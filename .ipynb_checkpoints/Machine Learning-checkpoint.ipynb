# %% [markdown]
# # Machine Learning
# ## Anna Bernbaum
# ## April 2019

# %% [markdown]
# The audio clips have been downloaded using `Downloading Google Audioset clips.ipynb` into a directory structure as shown below:
#
# `|-- AudioSet_WAV_files
#     |-- Coughs
#     |-- Speech`
#
# Coughs and Speech both contain the same number of audio clips. Most are 10 seconds long but not all.
#
# Remaining concerns:
# - Some clips have trailing silence that could be trimmed
# - Is it an issue that clips are different lengths?
# - Many clips contain audible noises as well as coughing/speech. These are likely labelled with multiple tags. Shouls these be removed?
# - Clips are different lengths, a few are shorter than 10 seconds - this could become a problem
# - mel-spectrograms v normal spectrograms
# - Should I trim off the higher frequencies?
# - What layers should i use?
# - Should i do one-hot encoding

# %%
import tensorflow as tf
import keras
import kapre
from kapre.time_frequency import Spectrogram, Melspectrogram
import numpy as np
from keras.callbacks import EarlyStopping
import collections
from datetime import datetime
now = datetime.now()
import librosa
from librosa import display
import os
from sklearn import metrics
import itertools
from keras.models import load_model


# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

plt.rc('xtick',labelsize=16)
plt.rc('ytick',labelsize=16)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Helper functions

# %%
def print_info():
    '''Print system information'''
    
    print('%s/%s/%s' % (now.year, now.month, now.day))
    print('librosa version: {}'.format(librosa.__version__))
    print('Keras version: {}'.format(keras.__version__))
    if keras.backend._BACKEND == 'tensorflow':
        import tensorflow
        print('Keras backend: {}: {}'.format(keras.backend._backend, tensorflow.__version__))
    elif keras.backend._BACKEND == 'theano':
        import theano
        print('Keras backend: {}: {}'.format(keras.backend._backend, theano.__version__))
    print('Keras image data format: {}'.format(keras.backend.image_data_format()))
    print('Kapre version: {}'.format(kapre.__version__))
    print('\nSampling rate: {} Hz'.format(SR))

def check_model(model):
    '''Compile and fit the model'''

    model.summary(line_length=80, positions=[.33, .65, .8, 1.])

    batch_input_shape = (6,) + model.input_shape[1:]
    batch_output_shape = (6,) + model.output_shape[1:]
    model.compile(optimizer='sgd', loss='mse')  # Stochastic gradient descent optimizer, mean squared error loss function
    
    # train the model:
    model.fit(np.random.uniform(size=batch_input_shape), np.random.uniform(size=batch_output_shape), epochs=1)

# function to plot spectrogram
def visualise_model(model, logam=False):
    '''Plot spectrogram'''

    n_ch, nsp_src = model.input_shape[1:]
    src, _ = librosa.load('../SoloProject/AudioSet_WAV_files/Speech/0oLuOoKzIbI.wav', sr=SR, mono=True)
    print("original:", src.shape)
    src = src[:nsp_src]  # making the clip the specified length
    print("trimmed:", src.shape)
    src_batch = src[np.newaxis, np.newaxis, :]
    print("trimmed again:", src_batch.shape)
    
    pred = model.predict(x=src_batch)
    
    if keras.backend.image_data_format == 'channels_first':
        result = pred[0, 0]
    else:
        result = pred[0, :, :, 0]
    
    if logam:
        result = librosa.power_to_db(result)
    display.specshow(result, 
                     y_axis='linear', sr=SR)    
    
def plot_confusion_matrix(cm, title='Confusion matrix', cmap=plt.cm.Purples):
    '''Plot Confusion Matrix'''
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)
    
    #!!!!!! NOTE THAT THESE LABELS MAY BE BACKWARDS
    plt.xticks(tick_marks, ['Cough','Speech'], rotation=45)
    plt.yticks(tick_marks, ['Cough','Speech'])
    
    fmt = 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=18)
    plt.xlabel('Predicted label', fontsize=18)
    plt.grid(b=None)
    
def plot_norm_confusion_matrix(cm, title='Normalised Confusion matrix', cmap=plt.cm.Purples):
    '''Plot Confusion Matrix'''
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(2)
    
    #!!!!!! NOTE THAT THESE LABELS MAY BE BACKWARDS
    plt.xticks(tick_marks, ['Cough','Speech'], rotation=45)
    plt.yticks(tick_marks, ['Cough','Speech'])
    
    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label', fontsize=18)
    plt.xlabel('Predicted label', fontsize=18)
    plt.grid(b=None)

# %% [markdown]
# # Generating Spectrograms

# %% [markdown]
# ### Generating the spectrograms as part of the model

# %%
SR = 16000
sr = 22050

src_cute, _ = librosa.load('../SoloProject/AudioSet_WAV_files/Speech/0oLuOoKzIbI.wav', sr=SR, mono=True)

src = np.random.random((1, SR * 3))

input_shape = (1, SR)

model = keras.Sequential()
# model.add(Spectrogram(n_dft=128, n_hop=64, input_shape=src.shape, 
#           return_decibel_spectrogram=False, power_spectrogram=2.0, 
#           trainable_kernel=False, name='static_stft'))

model.add(Melspectrogram(n_dft=512, n_hop=256, input_shape=input_shape,
                         padding='same', sr=sr, n_mels=64,
                         fmin=0.0, fmax=10000, power_melgram=1.0,
                         return_decibel_melgram=True, trainable_fb=False,
                         trainable_kernel=False,
                         name='trainable_stft'))

check_model(model)
plt.figure(figsize=(14, 4))
plt.subplot(1, 2, 1)
plt.title('Spectrogram by Kapre', fontsize=22)
plt.ylabel('Frequency (Hz)', fontsize=18)
plt.xlabel('Time (s)', fontsize=18)

visualise_model(model, logam=False)  # if melspec, logam = false
plt.subplot(1, 2, 2)
display.specshow(librosa.power_to_db(np.abs(librosa.stft(src_cute[: SR * 3], 512, 256)) ** 2, ref=1.0), 
                         y_axis='linear', sr=SR)
plt.title('log-Spectrogram by Librosa')
# Out:
# WARNING:tensorflow:From /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# ________________________________________________________________________________
# Layer (type)              Output Shape              Param #
# ...
# trainable_stft (Melspectr (None, 64, 63, 1)         279616
# ...
# Total params: 279,616
# Trainable params: 0
# Non-trainable params: 279,616
# ________________________________________________________________________________
# Epoch 1/1
# 6/6 [==============================] - 0s 20ms/step - loss: 165.4510
# original: (160000,)
# trimmed: (16000,)
# trimmed again: (1, 1, 16000)
# Text(0.5, 1.0, 'log-Spectrogram by Librosa')

# %% [markdown]
# # Load and split the dataset

# %%
# load in samples from directory
# librosa.load()

total_number = 0
for clip in os.listdir("Audioset_WAV_files/Speech/"):
    if clip.endswith('.wav'):
        total_number += 1
        
total_number = total_number*2
split1 = int(0.6*total_number)
split2 = int(0.8*total_number)

# create empty arrays for the audio data and labels
audio = np.empty([total_number, 1, 220500])
labels = np.empty([total_number, 1])


# one hot vectors : keras.utils.np_utitls.to_categorical.

# Add the audio and labels to the empty arrays
i = 0
for clip in os.listdir("Audioset_WAV_files/Speech/"):
    if clip.endswith('.wav'):
        y, sr = librosa.load("Audioset_WAV_files/Speech/" + clip, mono=True) # trim a 10 second segment from start_time    
        audio[i, 0] = y
        labels[i] = 0
        i = i + 1  
        
for clip in os.listdir("Audioset_WAV_files/Coughs/"):
    if clip.endswith('.wav'):
        y, sr = librosa.load("Audioset_WAV_files/Coughs/" + clip, mono=True) # trim a 10 second segment from start_time    
        audio[i, 0] = y
        labels[i] = 1
        
        i = i + 1

# Shuffle the files
permutation = np.random.permutation(audio.shape[0])
shuffled_audio = audio[permutation]
shuffled_labels = labels[permutation]

# Split into 2 groups
train_audio = shuffled_audio[:split1]
train_labels = shuffled_labels[:split1]

validate_audio = shuffled_audio[split1:split2]
validate_labels = shuffled_labels[split1:split2]

test_audio = shuffled_audio[split2:]
test_labels = shuffled_labels[split2:]

print('train audio shape:', train_audio.shape)
print('train labels shape:', train_labels.shape)

print('validate audio shape:', validate_audio.shape)
print('validate labels shape:', validate_labels.shape)

print('test audio shape:', test_audio.shape)
print('test labels shape:', test_labels.shape)
# Out:
# train audio shape: (266, 1, 220500)
# train labels shape: (266, 1)
# validate audio shape: (89, 1, 220500)
# validate labels shape: (89, 1)
# test audio shape: (89, 1, 220500)
# test labels shape: (89, 1)

# %% [markdown]
# ## Check the balance of each set

# %%
test = train_labels.reshape(1, len(train_labels))

for i in test:
    count = collections.Counter(np.array(i))

print(count)
# Out:
# Counter({1.0: 134, 0.0: 132})

# %% [markdown]
# # Set up the layers
#
# Use this space to test different models, record all results in the tracking spreadsheet.

# %%
model = keras.Sequential()

input_shape = (1, 220500)

sr = 22050  # Sampling rate of the audio


model.add(Melspectrogram(n_dft=512, n_hop=256, input_shape=input_shape,
                         padding='same', sr=sr, n_mels=128,
                         fmin=0.0, fmax=sr/2, power_melgram=1.0,
                         return_decibel_melgram=False, trainable_fb=False,
                         trainable_kernel=False,
                         name='trainable_stft'))


model.add(keras.layers.Conv2D(128, [7,11], strides=[2,2], padding = 'SAME'))

model.add(keras.layers.LeakyReLU(alpha=0.1))

model.add(keras.layers.MaxPool2D(pool_size=(2,2), padding='SAME'))

model.add(keras.layers.Conv2D(128, [7,11], strides=[2,2], padding = 'SAME'))

model.add(keras.layers.LeakyReLU(alpha=0.1))


model.add(keras.layers.Dropout(0.2))


model.add(keras.layers.Flatten())
model.add(keras.layers.Dense(1, activation='sigmoid'))
    

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# trainable_stft (Melspectrogr (None, 128, 862, 1)       296064
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 64, 431, 128)      9984
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 64, 431, 128)      0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 32, 216, 128)      0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 16, 108, 128)      1261696
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 16, 108, 128)      0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 108, 128)      0
# ...

# %% [markdown]
# # Compile the model

# %%
keras.optimizers.Adam(lr=0.001)  # set the learning rate

model.compile(optimizer='adam', loss='binary_crossentropy', metrics = ['acc'])

# %% [markdown]
# # Train the model

# %%
early_stopping_monitor = EarlyStopping(patience=2)

# Use early stopping
# history = model.fit(train_audio, train_labels, epochs=15, validation_data=[validate_audio, validate_labels], callbacks=[early_stopping_monitor])

# Dont use early stopping
history = model.fit(train_audio, train_labels, epochs=15, validation_data=[validate_audio, validate_labels])
# Out:
# Train on 266 samples, validate on 89 samples
# Epoch 1/15
# 266/266 [==============================] - 54s 202ms/step - loss: 4.3622 - acc: 0.5000 - val_loss: 0.9641 - val_acc: 0.3596
# Epoch 2/15
# 266/266 [==============================] - 62s 232ms/step - loss: 0.9800 - acc: 0.3797 - val_loss: 0.7051 - val_acc: 0.5281
# Epoch 3/15
# 266/266 [==============================] - 53s 198ms/step - loss: 0.6546 - acc: 0.6767 - val_loss: 0.5478 - val_acc: 0.7978
# Epoch 4/15
# 266/266 [==============================] - 63s 239ms/step - loss: 0.6632 - acc: 0.7895 - val_loss: 0.8372 - val_acc: 0.6966
# Epoch 5/15
# 266/266 [==============================] - 63s 238ms/step - loss: 0.4693 - acc: 0.8120 - val_loss: 0.4229 - val_acc: 0.8764
# Epoch 6/15
# 266/266 [==============================] - 62s 234ms/step - loss: 0.3962 - acc: 0.8459 - val_loss: 0.4061 - val_acc: 0.8202
# Epoch 7/15
# ...

# %% [markdown]
# ## Model Training History

# %%
# summarize history for accuracy
plt.plot(history.history['acc'], '#4ba899')
plt.plot(history.history['val_acc'], '#3800b2')
plt.title('Model Accuracy', fontsize=22)
plt.ylabel('Accuracy', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(history.history['loss'], '#4ba899')
plt.plot(history.history['val_loss'], '#3800b2')
plt.title('Model Loss', fontsize=22)
plt.ylabel('Loss', fontsize=18)
plt.xlabel('Epoch', fontsize=18)
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # Evaluate the Model

# %%
test_loss, test_accuracy = model.evaluate(test_audio, test_labels)
validation_loss, validation_accuracy = model.evaluate(validate_audio, validate_labels)


print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
print('Validation Loss:', validation_loss)
print('Validation Accuracy:', validation_accuracy)
# Out:
# ...
# 89/89 [==============================] - 4s 41ms/step
# Test Loss: 0.6725398978490508
# Test Accuracy: 0.7640449411413642
# Validation Loss: 0.35520497064911916
# Validation Accuracy: 0.8202247271377049

# %% [markdown]
# # Make predictions

# %%
predictions = model.predict(test_audio)

print('Highest Label Confidence Value:', np.argmax(predictions[1]))

# check if prediction is correct
print('Actual Label:', test_labels[1])
# Out:
# Highest Label Confidence Value: 0
# Actual Label: [1.]

# %% [markdown]
# ## Confusion Matrix

# %%
# Round the predictions to 1 or 0 as the bianry options
rounded_predictions = []
for i in predictions:
    for j in i:
        j = int(round(j))
        rounded_predictions.append(j)

cm = metrics.confusion_matrix(test_labels, rounded_predictions, labels=None, sample_weight=None)
plot_confusion_matrix(cm)

tn, fp, fn, tp = cm.ravel()
print("True Negatives: ",tn) 
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)

# Normalised confusion matrix
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_norm_confusion_matrix(cm_norm)
# Out:
# True Negatives:  42
# False Positives:  1
# False Negatives:  5
# True Positives:  41

# %% [markdown]
# # Save the model

# %%
filename = 'name.h5'  # change the file name
filepath = 'Saved Keras Models/' + filename
model.save(filepath)

# %% [markdown]
# # Load in a previous model

# %%
# model2 = load_model('Saved Keras Models/OPALS.h5', custom_objects={'Melspectrogram':kapre.time_frequency.Melspectrogram})
model2 = load_model('Saved Keras Models/QUERY.h5', custom_objects={'Melspectrogram':kapre.time_frequency.Melspectrogram})

# %% [markdown]
# ## Model Details

# %%
print(model2.summary())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# trainable_stft (Melspectrogr (None, 128, 862, 1)       296064
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 64, 431, 128)      9984
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 64, 431, 128)      0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 216, 128)      0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 16, 108, 128)      1261696
# _________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)   (None, 16, 108, 128)      0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 108, 128)      0
# ...

# %% [markdown]
# ## Evaluate on Test Set

# %%
predictions = model2.predict(test_audio)

# Round the predictions to 1 or 0 as the bianry options
rounded_predictions = []
for i in predictions:
    for j in i:
        j = int(round(j))
        rounded_predictions.append(j)

cm = metrics.confusion_matrix(test_labels, rounded_predictions, labels=None, sample_weight=None)
plot_confusion_matrix(cm)

tn, fp, fn, tp = cm.ravel()
print("True Negatives: ",tn) 
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)

# Normalised confusion matrix
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_norm_confusion_matrix(cm_norm)

test_loss, test_accuracy = model.evaluate(test_audio, test_labels)
validation_loss, validation_accuracy = model.evaluate(validate_audio, validate_labels)

print('Test Loss:', test_loss)
print('Test Accuracy:', test_accuracy)
print('Validation Loss:', validation_loss)
print('Validation Accuracy:', validation_accuracy)
# Out:
# True Negatives:  42
# False Positives:  1
# False Negatives:  5
# True Positives:  41
# ...
# 89/89 [==============================] - 4s 45ms/step
# Test Loss: 0.6725398978490508
# Test Accuracy: 0.7640449411413642
# Validation Loss: 0.35520497064911916
# Validation Accuracy: 0.8202247271377049

# %% [markdown]
# ## Evaluate on my own recordings

# %% [markdown]
# ### Load in the data

# %%
# Add the audio and labels to the empty arrays
# create empty arrays for the audio data and labels
total_number = 16

my_audio = np.empty([total_number, 1, 220500])
my_labels = np.empty([total_number, 1])


i = 0
for clip in os.listdir("my_recordings_machinelearning/Speech/"):
    if clip.endswith('.m4a'):
        y, sr = librosa.load("my_recordings_machinelearning/Speech/" + clip, mono=True) # trim a 10 second segment from start_time    
        
        # Make all clips 10 seconds long
        if len(y) < 220500: 
            N = 220500-len(y)
            y = np.pad(y, (0, N), 'constant')
        
        # Make all clips 10 seconds long
        if len(y) > 220500:
            y = y[0:220500]
        
        my_audio[i, 0] = y
        my_labels[i] = 0
        i = i + 1  
        
for clip in os.listdir("my_recordings_machinelearning/Coughs/"):
    if clip.endswith('.m4a'):
        y, sr = librosa.load("my_recordings_machinelearning/Coughs/" + clip, mono=True) # trim a 10 second segment from start_time    
                
        # Make all clips 10 seconds long
        if len(y) < 220500:
            N = 220500-len(y)
            y = np.pad(y, (0, N), 'constant')

        # Make all clips 10 seconds long
        if len(y) > 220500:
            y = y[0:220500]
            
        my_audio[i, 0] = y
        my_labels[i] = 1
        
        i = i + 1

# %% [markdown]
# ## Make Predictions

# %%
predictions = model2.predict(my_audio)

rounded_predictions = []
for i in predictions:
    for j in i:
        j = int(round(j))
        rounded_predictions.append(j)

cm = metrics.confusion_matrix(my_labels, rounded_predictions, labels=None, sample_weight=None)
plot_confusion_matrix(cm)

# Normalised confusion matrix
cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
plt.figure()
plot_norm_confusion_matrix(cm_norm)

tn, fp, fn, tp = cm.ravel()
print("True Negatives: ",tn) 
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  7
# False Positives:  1
# False Negatives:  2
# True Positives:  6
