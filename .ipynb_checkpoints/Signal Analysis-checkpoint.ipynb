# %% [markdown]
# # Solo Project Signal Analysis
# ## Anna Bernbaum
# ### 2019

# %%
import wave
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os as os
import librosa
from scipy.signal import hilbert
from sklearn import decomposition, preprocessing
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 5]

# %% [markdown]
# ## Defining Functions and Constants

# %%
fs = 44100  # Sampling frequency

def import_data(filepath):
    """Import a signal from a .wav file as an array"""

    data = wave.open(filepath)
    # Extract Raw Audio from Wav File
    signal = data.readframes(-1)
    signal = np.fromstring(signal, 'Int16')
    name = os.path.basename(filepath)
    return signal, name

def basic_plot(signal, name):
    time_values = np.arange(0,(len(signal))/fs, 1/fs)  # convert from smaple number to time
    plt.title(name)
    plt.xlabel('Time (s)')
    plt.ylabel('Amplitude Normalised')
    plt.plot(time_values, signal)
    plt.grid()
    plt.show()

# %% [markdown]
# # FIRST TESTS
# The First round of tests focussed on testing a variety of different technologies.
# ## Import Data

# %%
# Load in data to pandas dataframe

# FIRST SET OF TESTS
filepaths = ['my_WAV_files/Tests 1/DPA_tests1/DPA_breathing1.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_breathing2.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_breathing3.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_forced_breathing1.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_forced_breathing2.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_forced_breathing3.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_cough1.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_cough2.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_cough3.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_wheeze1.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_wheeze2.wav',
             'my_WAV_files/Tests 1/DPA_tests1/DPA_wheeze3.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_breathing1.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_breathing2.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_breathing3.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_forced_breathing1.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_forced_breathing2.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_forced_breathing3.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_cough1.wav',
             'my_WAV_files/Tests 1/DPA_stethescope_tests1/DPA_stethescope_wheeze1.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_breathing1.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_breathing2.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_breathing3.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_forced_breathing1.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_forced_breathing2.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_forced_breathing3.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_cough1.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_cough2.wav',
             'my_WAV_files/Tests 1/Cducer_tests1/Cducer_cough3.wav',
             ]





df = pd.DataFrame()  # create empty dataframe


# import data for every file of collected data
for file in filepaths:
    signal, name = import_data(file)
    df1 = pd.DataFrame(signal, columns=[name])
    df = pd.concat([df, df1], ignore_index=False, axis=1 )

# # import data for every file of collected data
# for file in filepaths:
#     signal, name = import_data(file)
#     df[name] = pd.Series(signal)  # append signal to new column in pandas df
# Out:
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   if __name__ == '__main__':
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   if __name__ == '__main__':

# %% [markdown]
# ## Plot the signal

# %%
# Basic Plotting
signal = (df['DPA_stethescope_forced_breathing1.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Acetate Cough')

# %% [markdown]
# ## Remove Noise

# %% [markdown]
# ## Outlier Handling
# ### Identify Outliers

# %%
# Remove outliers
window = int(0.05 * fs)  # window size in sample number
threshold = 8000

# https://ocefpaf.github.io/python4oceanographers/blog/2015/03/16/outlier_detection/
df['median'] = df['DPA_stethescope_forced_breathing1.wav'].rolling(window).median()
difference = np.abs(df['DPA_stethescope_forced_breathing1.wav'] - df['median'])
outlier_idx = difference > threshold

# %% [markdown]
# ### Plot Outliers

# %%
# Plot outliers
time_values = np.arange(0, (len(df['DPA_stethescope_forced_breathing1.wav'])) / fs, 1 / fs)  # convert from sample number to time
plt.figure(1)
plt.title('Outlier Detection')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude Normalised')
plt.plot(time_values, df['DPA_stethescope_forced_breathing1.wav'])
plt.plot(time_values[outlier_idx], df['DPA_stethescope_forced_breathing1.wav'][outlier_idx], 'x')
plt.show()

# %% [markdown]
# ### Remove Outliers

# %%
# THIS TAKES FOREVER TO RUN????
# remove points either side of outliers

# create duplicate column for editing
df['RemovedOutliers'] = df['DPA_stethescope_forced_breathing1.wav']

removal_length = 1000

for i in np.arange(0, len(df['RemovedOutliers'])):
    if outlier_idx[i] == True:
        current = df['RemovedOutliers'][i]
        replace_range = df['RemovedOutliers'][i-removal_length : i+removal_length]
        # df['RemovedOutliers'].replace(current, np.nan)
        # print('outliers')
        if len(df['RemovedOutliers']) - i > len(replace_range): # if theres enough space
            df['RemovedOutliers'].loc[i-removal_length:i+removal_length] = np.nan
    else:
        pass
# Out:
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:189: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %% [markdown]
# ### Plot the data with removed outliers

# %%
time_values = np.arange(0,(len(df['RemovedOutliers']))/fs, 1/fs)  # convert from smaple number to time
plt.title('Missing Outliers (Heartbeats)')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude Normalised')
plt.plot(time_values, df['DPA_stethescope_forced_breathing1.wav'])
plt.plot(time_values, df['RemovedOutliers'])
plt.legend(['Original Signal', 'Removed Outliers'], loc='lower left')
plt.show()

# %% [markdown]
# ### Interpolate Data Gaps

# %%
# interpolate gaps
df['RemovedOutliers'] = df['RemovedOutliers'].interpolate(method = 'linear')


# plot interpolated results
basic_plot(df['RemovedOutliers'], 'Interpolated Signal')

# %% [markdown]
# ## Plot Spectrogram

# %%
plt.specgram(df['RemovedOutliers'], Fs=fs)
plt.title('DPA Stethoscope removed outliers')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

# creating custom spectrograms: https://stackoverflow.com/questions/19468923/cutting-of-unused-frequencies-in-specgram-matplotlib

# %% [markdown]
# Trimmed to the relevant portion

# %%
ymax = 10000

plt.specgram(df['RemovedOutliers'], Fs=fs)
plt.axis(ymin=0, ymax=ymax)
# plt.yscale('log')
plt.title('DPA Stethoscope Removed Outliers')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

# %% [markdown]
# ## Plot RMS
#
# UNFINISHED

# %%
# analytic_signal = hilbert(df['RemovedOutliers'])
# amplitude_envelope = np.abs(analytic_signal)

def window_rms(inputSignal, window_size):
    a2 = np.power(inputSignal,2)
    window = np.ones(window_size)/float(window_size)
    return np.sqrt(np.convolve(a2, window, 'valid'))

# upper_values = abs(df['RemovedOutliers'])
# upper = df['RemovedOutliers'][df['RemovedOutliers'] > 0]
upper = df['RemovedOutliers'].copy()
upper[upper < 0] = np.nan
# lower = df['RemovedOutliers'][df['RemovedOutliers'] < 0]


print(len(upper))

upper_envelope = window_rms(upper,300) ##envolvente Rms (second parameter is windows size)
# lower_envelope = window_rms(lower,6000) ##envolvente Rms (second parameter is windows size)

plt.plot(df['RemovedOutliers'])
plt.plot(upper_envelope)
# plt.plot(lower_envelope)
plt.xlabel("time in seconds")
plt.legend(['Removed Outliers Signal', 'Upper Envelope'], loc='lower left')
plt.show()
# Out:
# 608667

# %% [markdown]
# # SECOND ROUND OF TESTS

# %%
df2 = pd.DataFrame()  # create empty dataframe

# SECOND ROUND OF TESTS
filepaths = ['my_WAV_files/Tests 2/casper_glove_cough.wav',
             'my_WAV_files/Tests 2/casper_glove_shallow.wav',
             'my_WAV_files/Tests 2/casper_glove_forced.wav',
             'my_WAV_files/Tests 2/casper_acetate_cough.wav',
             'my_WAV_files/Tests 2/casper_acetate_shallow.wav',
             'my_WAV_files/Tests 2/casper_acetate_forced.wav',
             'my_WAV_files/Tests 2/casper_covered_glove_cough.wav',
             'my_WAV_files/Tests 2/casper_covered_glove_shallow.wav',
             'my_WAV_files/Tests 2/casper_covered_glove_forced.wav',
             'my_WAV_files/Tests 2/casper_covered_acetate_cough.wav',
             'my_WAV_files/Tests 2/casper_covered_acetate_shallow.wav',
             'my_WAV_files/Tests 2/casper_covered_acetate_forced.wav',
             'my_WAV_files/Tests 2/single_cducer_cough.wav',
             'my_WAV_files/Tests 2/single_cducer_shallow.wav',
             'my_WAV_files/Tests 2/single_cducer_forced.wav',
             'my_WAV_files/Tests 2/stethoscope_cough.wav',
             'my_WAV_files/Tests 2/stethoscope_shallow.wav',
             'my_WAV_files/Tests 2/stethoscope_forced.wav'
            ]



# import data for every file of collected data
for file in filepaths:
    signal, name = import_data(file)
    df = pd.DataFrame(signal, columns=[name])
    df2 = pd.concat([df, df2], ignore_index=False, axis=1)
# Out:
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: Numeric-style type codes are deprecated and will result in an error in the future.
#   if __name__ == '__main__':
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   if __name__ == '__main__':

# %% [markdown]
# ## Plot the Signal

# %% [markdown]
# ### Cough

# %%
# Basic Plotting
signal = (df2['casper_acetate_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Acetate Cough')

signal = (df2['casper_glove_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Glove Cough')

signal = (df2['casper_covered_acetate_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Cough')

signal = (df2['casper_covered_glove_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Cough')

signal = (df2['single_cducer_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Single CDucer Cough')

signal = (df2['stethoscope_cough.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Stethoscope Cough')

# %% [markdown]
# ### Forced Breathing

# %%
# Basic Plotting
# TODO: fix the plots being cropped on the x axis?

signal = (df2['casper_acetate_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Acetate Forced Breathing')

signal = (df2['casper_glove_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Glove Forced Breathing')

signal = (df2['casper_covered_acetate_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Forced Breathing')

signal = (df2['casper_covered_glove_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Forced Breathing')

signal = (df2['single_cducer_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Single CDucer Forced Breathing')

signal = (df2['stethoscope_forced.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Stethoscope Forced Breathing')

# %% [markdown]
# ### Shallow Breathing

# %%
# Basic Plotting
signal = (df2['casper_acetate_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Acetate Shallow Breathing')

signal = (df2['casper_glove_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Glove Shallow Breathing')

signal = (df2['casper_covered_acetate_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Shallow Breathing')

signal = (df2['casper_covered_glove_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Casper Covered Acetate Shallow Breathing')

signal = (df2['single_cducer_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Single CDucer Shallow Breathing')

signal = (df2['stethoscope_shallow.wav'])  # Change this to the desired signal to plot
basic_plot(signal, 'Stethoscope Shallow Breathing')

# %% [markdown]
# ## Outlier Handling

# %% [markdown]
# ### Identify Outliers

# %%
# Remove outliers
window = int(0.05 * fs)  # window size in sample number
threshold = 8000

# https://ocefpaf.github.io/python4oceanographers/blog/2015/03/16/outlier_detection/
df2['median'] = df2['single_cducer_shallow.wav'].rolling(window).median()
difference = np.abs(df2['single_cducer_shallow.wav'] - df2['median'])
outlier_idx = difference > threshold

# %% [markdown]
# ### Plot Outliers

# %%
# Plot outliers
time_values = np.arange(0, (len(df2['single_cducer_shallow.wav'])) / fs, 1 / fs)  # convert from sample number to time
plt.figure(1)
plt.title('Outlier Detection')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude Normalised')
plt.plot(time_values, df2['single_cducer_shallow.wav'])
plt.plot(time_values[outlier_idx], df2['single_cducer_shallow.wav'][outlier_idx], 'x')
plt.show()

# %% [markdown]
# ## Plot Spectrograms

# %%
plt.specgram(df2['single_cducer_shallow.wav'], Fs=fs)
plt.title('single_cducer_shallow.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

plt.specgram(df2['single_cducer_cough.wav'], Fs=fs)
plt.title('single_cducer_cough.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

plt.specgram(df2['single_cducer_forced.wav'], Fs=fs)
plt.title('single_cducer_forced.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()


plt.specgram(df2['single_cducer_shallow.wav'], Fs=fs)
plt.axis(ymin=0, ymax=10000)
plt.yscale('log')

# %% [markdown]
# Trimmed to the relevant portion

# %%
ymax = 10000

plt.specgram(df2['single_cducer_shallow.wav'], Fs=fs)
plt.axis(ymin=0, ymax=ymax)
# plt.yscale('log')
plt.title('single_cducer_shallow.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

plt.specgram(df2['single_cducer_cough.wav'], Fs=fs)
plt.axis(ymin=0, ymax=ymax)
# plt.yscale('log')
plt.title('single_cducer_cough.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

plt.specgram(df2['single_cducer_forced.wav'], Fs=fs)
plt.axis(ymin=0, ymax=ymax)
# plt.yscale('log')
plt.title('single_cducer_forced.wav')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (kHz)')
plt.show()

# %% [markdown]
# # Principal Component Analysis (PCA)

# %% [markdown]
# ## Calculate the PCA

# %%
def compute_pca(data):
    # compute features
    data = data.dropna()
    data = data.as_matrix()
    data = data.astype(np.float)
    X = librosa.feature.mfcc(data, sr=fs)

    # Scale the features to have 0 mean and unit variance
    X = preprocessing.scale(X)
    X.mean()

    # create PCA model object
    model = decomposition.PCA(n_components=2, whiten=True)

    # Apply the PCA to the scaled features
    model.fit(X.T)

    Y = model.transform(X.T)
#     print('PCA results shape:', Y.shape)
    
    # # Lets see how many model components are returned 
#     print('Number of returned components:', model.components_.shape)

    return Y

# %% [markdown]
# ### For the full signal

# %%
Y = compute_pca(df2['single_cducer_shallow.wav'])
plt.scatter(Y[:,0], Y[:,1])

Y = compute_pca(df2['single_cducer_forced.wav'])
plt.scatter(Y[:,0], Y[:,1])

Y = compute_pca(df2['single_cducer_cough.wav'])
plt.scatter(Y[:,0], Y[:,1])

plt.legend(['Shallow', 'Forced', 'Cough'])
plt.title('PCA components for Single CDucer recordings')
plt.grid()
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# Text(0, 0.5, 'PC2')

# %% [markdown]
# ## For the cropped segments

# %%
# Trim to just the cough 

def crop_signal(data, start_time, end_time):
    start_point = int(start_time * fs)
    end_point = int(end_time * fs)
    data = df2[data][start_point:end_point]
    return data

plt.figure()
data = crop_signal('single_cducer_cough.wav', 1.6, 2.4)
# basic_plot(data, 'Cropped Cough 1')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_cough.wav', 4.3, 5)
# basic_plot(data, 'Cropped Cough 2')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_cough.wav', 7, 7.8)
# basic_plot(data, 'Cropped Cough 3')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

plt.legend(['Cough 1', 'Cough 2', 'Cough 3'])
plt.title('PCA components for Single CDucer recordings')
plt.grid()
plt.xlabel('PC1')
plt.ylabel('PC2')


# Trim to just the shallow breath
plt.figure()
data = crop_signal('single_cducer_shallow.wav', 0, 3)
# basic_plot(data, 'Cropped Cough 1')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_shallow.wav', 3, 5.8)
# basic_plot(data, 'Cropped Cough 2')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_shallow.wav', 5.8, 9)
# basic_plot(data, 'Cropped Cough 3')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

plt.legend(['Shallow 1', 'Shallow 2', 'Shallow 3'])
plt.title('PCA components for Single CDucer recordings')
plt.grid()
plt.xlabel('PC1')
plt.ylabel('PC2')


# Trim to just the forced breath
plt.figure()
data = crop_signal('single_cducer_forced.wav', 0, 2)
# basic_plot(data, 'Cropped Cough 1')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_forced.wav', 3, 6)
# basic_plot(data, 'Cropped Cough 2')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

data = crop_signal('single_cducer_forced.wav', 7, 10.9)
# basic_plot(data, 'Cropped Cough 3')
Y = compute_pca(data)
plt.scatter(Y[:,0], Y[:,1])

plt.legend(['Forced 1', 'Forced 2', 'Forced 3'])
plt.title('PCA components for Single CDucer recordings')
plt.grid()
plt.xlabel('PC1')
plt.ylabel('PC2')
# Out:
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# /Users/annabernbaum/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   after removing the cwd from sys.path.
# ...

# %% [markdown]
# # Automatically Identifying the Different areas
#
# If an audio sample containign both breathing and coughing was uploaded, could the script automatically label the various areas?

# %%
# Automatically identify the areas of cough?

# Event onset detection??
